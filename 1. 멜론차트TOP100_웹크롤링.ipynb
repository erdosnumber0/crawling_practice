# %%
# 크롬드라이버 다운받기
# https://sites.google.com/a/chromium.org/chromedriver/downloads
print('https://sites.google.com/a/chromium.org/chromedriver/downloads')
# Out:
# https://sites.google.com/a/chromium.org/chromedriver/downloads

# %%
# !pip install selenium

# %%
from selenium import webdriver
driver = webdriver.Chrome('C:\chrome\chromedriver.exe')

# %%
url = 'https://www.naver.com/'
driver.get(url)

# %%
# 웹페이지 html 다운로드
html=driver.page_source

# %%
# 예제 2-39 HTML 구조
html ='''
<html>
    <head>
    </head>
    <body>
        <h1> 우리동네시장</h1>
            <div class = 'sale'>
                <p id='fruits1' class='fruits'>
                    <span class = 'name'> 바나나 </span>
                    <span class = 'price'> 3000원 </span>
                    <span class = 'inventory'> 500개 </span>
                    <span class = 'store'> 가나다상회 </span>
                    <a href = 'http://bit.ly/forPlaywithData' > 홈페이지 </a>
                </p>
            </div>
            <div class = 'prepare'>
                <p id='fruits2' class='fruits'>
                    <span class ='name'> 파인애플 </span>
                </p>
            </div>
    </body>
</html>
'''

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(html, 'html.parser')

# %%
tags_span= soup.select('span') # 태그명이 span인 태그를 모두 찾아 저장
tags_p=soup.select('p') # 태그명이 p인 태그를 모두 찾아 저장

# %% [markdown]
# html 정보 찾기(태그)

# %%
# soup.select 조건 부분의 # 또는 . 뒤에 class
# id값은 특정 대상을 지정하기 위해 사용되므로 html 내에서 한 번만 사용 가능. id값을 
# 잘 활용한다면 특정 태그를 손쉽게 찾을 수 있다.
ids_fuits1=soup.select('#fruits1') 
class_price=soup.select('.price')
tags_span_class_price=soup.select('span.price')

# %% [markdown]
# html 정보 찾기(상위 구조 활용)

# %%
tags_name=soup.select('span.name')
print(tags_name) # class명이 name인 것 모두 출력
# Out:
# [<span class="name"> 바나나 </span>, <span class="name"> 파인애플 </span>]

# %%
tags_banana1=soup.select('#fruits1 > span.name')
print(tags_banana1) # id-> span.name을 함으로써 바나나만 출력되었다.
# Out:
# [<span class="name"> 바나나 </span>]

# %%
tags_banana2= soup.select('div.sale > #fruits1 > span.name')
tags_banana3= soup.select('div.sale span.name')
print(tags_banana2)
print(tags_banana3)
# Out:
# [<span class="name"> 바나나 </span>]
# [<span class="name"> 바나나 </span>]

# %% [markdown]
# 정보 가져오기

# %%
tags=soup.select('span.name')
tag_1=tags[0] # 인덱스 번호로 하나의 태그 지정하기
print(tag_1)
# Out:
# <span class="name"> 바나나 </span>

# %%
tags=soup.select('span.name')
for tag in tags:
    print(tag)
# Out:
# <span class="name"> 바나나 </span>
# <span class="name"> 파인애플 </span>

# %%
content = tag.text # 태그에서 화면에 보이는 텍스트 부분만 가져오기
attribute = tag['속성명'] # 태그 내 속성값 가져오기

# %%
tags = soup.select('a')
tag = tags[0]
content = tag.text
print(content)
link = tag['href'] # 하이퍼링크는 모두 <a href='url 주소'> 형식으로 작성되어 있다.
print(link)
# Out:
#  홈페이지
# http://bit.ly/forPlaywithData

# %%
from selenium import webdriver
driver = webdriver.Chrome('C:\chrome\chromedriver.exe')

# %%
url='http://www.melon.com/chart/index.htm'
driver.get(url)

# %%
html = driver.page_source
soup = BeautifulSoup(html,'html.parser')

# %%
songs=soup.select('table>tbody>tr')
print(len(songs))
print(songs[0])
# Out:
# 100
# <tr data-song-no="33359317">
# <td><div class="wrap t_right"><input class="input_check" name="input_check" title="Peaches (Feat. Daniel Caesar &amp; Giveon) 곡 선택" type="checkbox" value="33359317"/></div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10580103');" title="Justice">
# <img alt="Justice - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/105/80/103/10580103_20210319132819_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('33359317');" title="Peaches (Feat. Daniel Caesar &amp; Giveon) 곡정보"><span class="none">곡정보</span></a>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# ...

# %%
songs
# Out:
# [<tr data-song-no="33359317">
#  <td><div class="wrap t_right"><input class="input_check" name="input_check" title="Peaches (Feat. Daniel Caesar &amp; Giveon) 곡 선택" type="checkbox" value="33359317"/></div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10580103');" title="Justice">
#  <img alt="Justice - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/105/80/103/10580103_20210319132819_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
#  <td><div class="wrap">
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('33359317');" title="Peaches (Feat. Daniel Caesar &amp; Giveon) 곡정보"><span class="none">곡정보</span></a>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
# ...

# %%
song=songs[0]

# %%
title=song.select('a')
len(title)
# Out:
# 6

# %%
title = song.select('span>a')
len(title)
# Out:
# 2

# %%
title = song.select('div.ellipsis.rank01>span>a')[0].text
title
# Out:
# 'Peaches (Feat. Daniel Caesar & Giveon)'

# %%
title = song.select('div.ellipsis.rank01>span>a').text
title
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-5456e670e3bd> in <module>
# ----> 1 title = song.select('div.ellipsis.rank01>span>a').text
#       2 title
#
# C:\caba\anaconda\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    2158     def __getattr__(self, key):
#    2159         """Raise a helpful exception to explain a common code fix."""
# -> 2160         raise AttributeError(
#    2161             "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2162         )
#
# AttributeError: ResultSet object has no attribute 'text'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
singer = song.select('div.ellipsis.rank02>span>a')
len(singer)
# Out:
# 1

# %%
singer = song.select('div.ellipsis.rank02>a')[0].text
singer
# Out:
# '브레이브걸스'

# %% [markdown]
# 멜론 100위 노래 순위 정보 가져오기

# %%
for song in songs:
    title = song.select('div.ellipsis.rank01>span>a')[0].text
    singer = song.select('div.ellipsis.rank02>span>a')[0].text
    print(title, singer, sep='|')
# Out:
# 롤린 (Rollin')|브레이브걸스
# Peaches (Feat. Daniel Caesar & Giveon)|Justin Bieber
# 라일락|아이유
# 운전만해 (We Ride)|브레이브걸스
# Celebrity|아이유
# Timeless|SG 워너비
# 라라라|SG 워너비
# 내사람|SG 워너비
# Dynamite|방탄소년단
# 내 손을 잡아|아이유
# Coin|아이유
# LOVE DAY (2021) (바른연애 길잡이 X 양요섭, 정은지)|양요섭
# On The Ground|로제 (ROSÉ)
# 밝게 빛나는 별이 되어 비춰줄게|송이한
# 밤하늘의 별을(2020)|경서
# 멜로디|ASH ISLAND
# 잠이 오질 않네요|장범준
# 마.피.아. In the morning|ITZY (있지)
# 그냥 안아달란 말야|다비치
# 살다가|SG 워너비
# Blueming|아이유
# 취기를 빌려 (취향저격 그녀 X 산들)|산들
# 에잇(Prod.&Feat. SUGA of BTS)|아이유
# VVS (Feat. JUSTHIS) (Prod. GroovyRoom)|미란이 (Mirani)
# 어푸 (Ah puh)|아이유
# Lovesick Girls|BLACKPINK
# 사이렌 Remix (Feat. UNEDUCATED KID, Paul Blanco)|호미들
# 나랑 같이 걸을래 (바른연애 길잡이 X 적재)|적재
# 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야|장범준
# 12:45 (Stripped)|Etham
# 이 밤을 빌려 말해요 (바른연애 길잡이 X 10CM)|10CM
# 그날에 나는 맘이 편했을까|이예준
# 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지|AKMU (악동뮤지션)
# 오래된 노래|스탠딩 에그
# 추억은 만남보다 이별에 남아|정동하
# Savage Love (Laxed - Siren Beat) (BTS Remix)|Jawsh 685
# METEOR|창모 (CHANGMO)
# Dolphin|오마이걸 (OH MY GIRL)
# 2002|Anne-Marie
# ...

# %% [markdown]
# 최종 정리

# %%
from bs4 import BeautifulSoup
driver = webdriver.Chrome('C:\chrome\chromedriver.exe')
url = 'http://www.melon.com/chart/index.htm'
driver.get(url)
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

songs = soup.select('tr')[1:] # 오잉 이건 뭐지
for song in songs:
    title = song.select('div.ellipsis.rank01 > span > a')[0].text
    singer = song.select('div.ellipsis.rank02 > a')[0].text
    print(title, singer, sep= '|')
# Out:
# 롤린 (Rollin')|브레이브걸스
# Peaches (Feat. Daniel Caesar & Giveon)|Justin Bieber
# 라일락|아이유
# 운전만해 (We Ride)|브레이브걸스
# Celebrity|아이유
# Timeless|SG 워너비
# 라라라|SG 워너비
# 내사람|SG 워너비
# Dynamite|방탄소년단
# 내 손을 잡아|아이유
# Coin|아이유
# LOVE DAY (2021) (바른연애 길잡이 X 양요섭, 정은지)|양요섭
# On The Ground|로제 (ROSÉ)
# 밝게 빛나는 별이 되어 비춰줄게|송이한
# 밤하늘의 별을(2020)|경서
# 멜로디|ASH ISLAND
# 잠이 오질 않네요|장범준
# 마.피.아. In the morning|ITZY (있지)
# 그냥 안아달란 말야|다비치
# 살다가|SG 워너비
# Blueming|아이유
# 취기를 빌려 (취향저격 그녀 X 산들)|산들
# 에잇(Prod.&Feat. SUGA of BTS)|아이유
# VVS (Feat. JUSTHIS) (Prod. GroovyRoom)|미란이 (Mirani)
# 어푸 (Ah puh)|아이유
# Lovesick Girls|BLACKPINK
# 사이렌 Remix (Feat. UNEDUCATED KID, Paul Blanco)|호미들
# 나랑 같이 걸을래 (바른연애 길잡이 X 적재)|적재
# 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야|장범준
# 12:45 (Stripped)|Etham
# 이 밤을 빌려 말해요 (바른연애 길잡이 X 10CM)|10CM
# 그날에 나는 맘이 편했을까|이예준
# 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지|AKMU (악동뮤지션)
# 오래된 노래|스탠딩 에그
# 추억은 만남보다 이별에 남아|정동하
# Savage Love (Laxed - Siren Beat) (BTS Remix)|Jawsh 685
# METEOR|창모 (CHANGMO)
# Dolphin|오마이걸 (OH MY GIRL)
# 2002|Anne-Marie
# ...

# %% [markdown]
# selenium을 활용한 크롤링

# %%
driver = webdriver.Chrome('C:\chrome\chromedriver.exe')
url = 'http://www.melon.com/chart/index.htm'
driver.get(url)

songs = driver.find_elements_by_css_selector('tr')[1:]
for song in songs:
    title = song.find_elements_by_css_selector('div.ellipsis.rank01 > span > a')[0].text
    singer = song.find_elements_by_css_selector('div.ellipsis.rank02 > a')[0].text
    print(title, singer, sep = '|')
# Out:
# 롤린 (Rollin')|브레이브걸스
# Peaches (Feat. Daniel Caesar & Giveon)|Justin Bieber
# 라일락|아이유
# 운전만해 (We Ride)|브레이브걸스
# Celebrity|아이유
# Timeless|SG 워너비
# 라라라|SG 워너비
# 내사람|SG 워너비
# Dynamite|방탄소년단
# 내 손을 잡아|아이유
# Coin|아이유
# LOVE DAY (2021) (바른연애 길잡이 X 양요섭, 정은지)|양요섭
# On The Ground|로제 (ROSÉ)
# 밝게 빛나는 별이 되어 비춰줄게|송이한
# 밤하늘의 별을(2020)|경서
# 멜로디|ASH ISLAND
# 잠이 오질 않네요|장범준
# 마.피.아. In the morning|ITZY (있지)
# 그냥 안아달란 말야|다비치
# 살다가|SG 워너비
# Blueming|아이유
# 에잇(Prod.&Feat. SUGA of BTS)|아이유
# 취기를 빌려 (취향저격 그녀 X 산들)|산들
# VVS (Feat. JUSTHIS) (Prod. GroovyRoom)|미란이 (Mirani)
# Lovesick Girls|BLACKPINK
# 어푸 (Ah puh)|아이유
# 사이렌 Remix (Feat. UNEDUCATED KID, Paul Blanco)|호미들
# 나랑 같이 걸을래 (바른연애 길잡이 X 적재)|적재
# 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야|장범준
# 12:45 (Stripped)|Etham
# 이 밤을 빌려 말해요 (바른연애 길잡이 X 10CM)|10CM
# 그날에 나는 맘이 편했을까|이예준
# 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지|AKMU (악동뮤지션)
# 오래된 노래|스탠딩 에그
# 추억은 만남보다 이별에 남아|정동하
# Savage Love (Laxed - Siren Beat) (BTS Remix)|Jawsh 685
# METEOR|창모 (CHANGMO)
# Dolphin|오마이걸 (OH MY GIRL)
# 2002|Anne-Marie
# ...
